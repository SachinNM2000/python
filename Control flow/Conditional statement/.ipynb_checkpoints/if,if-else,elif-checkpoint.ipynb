# %%
#conditional statements
# if, if-else, elif

# %%
sal = 45000
if sal > 40000:
    print("Eligible for Marriage")
else:
    print("Not Eligible")
# Out:
# Eligible for Marriage

# %%
# Read number from keyboard and print Even number or Odd number
num= int(input("Enter a Number"))
if num%2==0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Enter a Number23
# Odd number

# %%
# Read number from keyboard and print days of week
num= int(input("Enter a Number:"))
if num==0:
    print("Sunday")
elif num==1:
    print("Monday")
elif num==2:
    print("Tuesday")
elif num==3:
    print("Wednesday")
elif num==4:
    print("Thursday")
elif num==5:
    print("Friday")
else:
    print("Tommorrow is Saturday")
# Out:
# Enter a Number:44
# Tommorrow is Saturday

# %%
#Check given number is 3-digit number or not
num=int(input("Enter a Number"))
if num>=100 and num<=999:
    print("Yes! Number is 3-digit number")
else:
    print("Not a 3-digit number")
# Out:
# Enter a Number777
# Yes! Number is 3-digit number
