# %%
# Set 
#   Collection of group of unique elements or values as one entity.
#   Duplicate elements are not allowed
#   Insertion order not preserved because indexing concept is not applicable

# %%
ids1=[101,102,103,104,105,101,102]
ids2=(101,102,103,104,105,101,102)
# list and tuple are allows the duplicate values
print(ids1)
print(ids2)
# Out:
# [101, 102, 103, 104, 105, 101, 102]
# (101, 102, 103, 104, 105, 101, 102)

# %%
ids={101,102,103,104,105,101,102}
print(ids) 
# removes the duplicate values
# Out:
# {101, 102, 103, 104, 105}

# %%
list=[]
tuple=()
set={}
dict={}

# %%
l1=[]
t1=()
s1={}
d1={}
print(type(l1))
print(type(t1))
print(type(s1))
print(type(d1))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>
# <class 'dict'>

# %%
# because, 
# {} creates an empty dictionary by default, not an empty set

# %%
#Set: stores the values
#dict: stores the key-value pairs

# %%
ids={101,102,103}
print(type(ids))
# Out:
# <class 'set'>
