# %%
#*** very important ****

# %%
#Dictionary : dict ?= {} 
#             JSON ?= {} (Javascript Object Notation)

# %%
# dictionary: word : meaning
#             ---------------
#             Mapped values
#             ---------------

# %%
# How to represents "Mapped values" in python?

# - group of key : value pairs as one entity

#NOTE: key : value pairs is also known as "Properties"
