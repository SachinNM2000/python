# %%
# Tuple: 
#       Immutable object, Read only object
#       cannot perform UPDATE and DELETE operations 
#       Collection of Heterogeneous elements

# %%
# Create-Tuple:
t1=()
t2=(10,20,30)
t3=100,200,300
t4=(10,20.5,'rahul',True)
print(type(t1))
print(type(t2))
print(type(t3))
print(type(t4))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>

# %%
enames=('rahul','sonia','priyanka')
print(enames[0])
print(enames[1])
print(enames[2])
print(enames[5])
# Out:
# rahul
# sonia
# priyanka
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-f63a60cc3c56> in <module>
#       3 print(enames[1])
#       4 print(enames[2])
# ----> 5 print(enames[5])
#
# IndexError: tuple index out of range
