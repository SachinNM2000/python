# %%
# Using concatination +


l1=[10,20,30]
l2=[40,50]

l3=l1+l2
print(l3)
# Out:
# [10, 20, 30, 40, 50]

# %%
l1=[10,20,30]
l2=[40,50]

l3=l1+40
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-a4e74d53eb7d> in <module>
#       2 l2=[40,50]
#       3
# ----> 4 l3=l1+40
#
# TypeError: can only concatenate list (not "int") to list

# %%
# repeatation *

l1=[10,20,30,40]
l2=l1*3
print(l2)
# Out:
# [10, 20, 30, 40, 10, 20, 30, 40, 10, 20, 30, 40]

# %%
# Membership operator
in , not in

# Identity operator
is ,is not
